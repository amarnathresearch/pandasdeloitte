# %%
import pandas as pd

# %%
df1 = pd.read_csv("climate_precip.csv")

# %%
df2 = pd.read_csv("climate_temp.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151110 entries, 0 to 151109
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   STATION                  151110 non-null  object
#  1   STATION_NAME             151110 non-null  object
#  2   DATE                     151110 non-null  int64
#  3   DLY-PRCP-25PCTL          151110 non-null  float64
#  4   DLY-SNWD-25PCTL          151110 non-null  int64
#  5   DLY-SNOW-25PCTL          151110 non-null  float64
#  6   DLY-PRCP-50PCTL          151110 non-null  float64
#  7   DLY-SNWD-50PCTL          151110 non-null  int64
#  8   DLY-SNOW-50PCTL          151110 non-null  float64
#  9   DLY-PRCP-75PCTL          151110 non-null  float64
#  10  DLY-SNWD-75PCTL          151110 non-null  int64
#  11  DLY-SNOW-75PCTL          151110 non-null  float64
#  12  MTD-PRCP-NORMAL          151110 non-null  float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127020 entries, 0 to 127019
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   STATION          127020 non-null  object
#  1   STATION_NAME     127020 non-null  object
#  2   ELEVATION        127020 non-null  object
#  3   LATITUDE         127020 non-null  object
#  4   LONGITUDE        127020 non-null  object
#  5   DATE             127020 non-null  int64
#  6   DLY-CLDD-BASE45  127020 non-null  int64
#  7   DLY-CLDD-BASE50  127020 non-null  int64
#  8   DLY-CLDD-BASE55  127020 non-null  int64
#  9   DLY-CLDD-BASE57  127020 non-null  int64
#  10  DLY-CLDD-BASE60  127020 non-null  int64
#  11  DLY-CLDD-NORMAL  127020 non-null  int64
#  12  DLY-CLDD-BASE70  127020 non-null  int64
#  13  DLY-CLDD-BASE72  127020 non-null  int64
#  14  DLY-HTDD-BASE40  127020 non-null  int64
#  15  DLY-HTDD-BASE45  127020 non-null  int64
# ...

# %%
df1.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# ...

# %%
output = pd.merge(df1, df2)

# %%
output.head(10)
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
# 5  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100106            -6.66
# 6  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100107            -6.66
# 7  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100108            -6.66
# 8  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100109            -6.66
# 9  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100110            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# ...

# %%
output.to_csv("output.csv")

# %%
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123005 entries, 0 to 123004
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   STATION                  123005 non-null  object
#  1   STATION_NAME             123005 non-null  object
#  2   DATE                     123005 non-null  int64
#  3   DLY-PRCP-25PCTL          123005 non-null  float64
#  4   DLY-SNWD-25PCTL          123005 non-null  int64
#  5   DLY-SNOW-25PCTL          123005 non-null  float64
#  6   DLY-PRCP-50PCTL          123005 non-null  float64
#  7   DLY-SNWD-50PCTL          123005 non-null  int64
#  8   DLY-SNOW-50PCTL          123005 non-null  float64
#  9   DLY-PRCP-75PCTL          123005 non-null  float64
#  10  DLY-SNWD-75PCTL          123005 non-null  int64
#  11  DLY-SNOW-75PCTL          123005 non-null  float64
#  12  MTD-PRCP-NORMAL          123005 non-null  float64
# ...

# %%
output = pd.merge(df1, df2, on=["STATION_NAME", "DATE"])

# %%
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123735 entries, 0 to 123734
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   STATION_x                123735 non-null  object
#  1   STATION_NAME             123735 non-null  object
#  2   DATE                     123735 non-null  int64
#  3   DLY-PRCP-25PCTL          123735 non-null  float64
#  4   DLY-SNWD-25PCTL          123735 non-null  int64
#  5   DLY-SNOW-25PCTL          123735 non-null  float64
#  6   DLY-PRCP-50PCTL          123735 non-null  float64
#  7   DLY-SNWD-50PCTL          123735 non-null  int64
#  8   DLY-SNOW-50PCTL          123735 non-null  float64
#  9   DLY-PRCP-75PCTL          123735 non-null  float64
#  10  DLY-SNWD-75PCTL          123735 non-null  int64
#  11  DLY-SNOW-75PCTL          123735 non-null  float64
#  12  MTD-PRCP-NORMAL          123735 non-null  float64
# ...

# %%
filter_prec_df = df1[df1['STATION'] == 'GHCND:USC00049099']

# %%
filter_prec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 364
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   STATION                  365 non-null    object
#  1   STATION_NAME             365 non-null    object
#  2   DATE                     365 non-null    int64
#  3   DLY-PRCP-25PCTL          365 non-null    float64
#  4   DLY-SNWD-25PCTL          365 non-null    int64
#  5   DLY-SNOW-25PCTL          365 non-null    float64
#  6   DLY-PRCP-50PCTL          365 non-null    float64
#  7   DLY-SNWD-50PCTL          365 non-null    int64
#  8   DLY-SNOW-50PCTL          365 non-null    float64
#  9   DLY-PRCP-75PCTL          365 non-null    float64
#  10  DLY-SNWD-75PCTL          365 non-null    int64
#  11  DLY-SNOW-75PCTL          365 non-null    float64
#  12  MTD-PRCP-NORMAL          365 non-null    float64
#  13  MTD-SNOW-NORMAL          365 non-null    float64
# ...

# %%
output1 = pd.merge(filter_prec_df, df2, on=["STATION_NAME", "DATE"])

# %%
output1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 364
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   STATION_x                365 non-null    object
#  1   STATION_NAME             365 non-null    object
#  2   DATE                     365 non-null    int64
#  3   DLY-PRCP-25PCTL          365 non-null    float64
#  4   DLY-SNWD-25PCTL          365 non-null    int64
#  5   DLY-SNOW-25PCTL          365 non-null    float64
#  6   DLY-PRCP-50PCTL          365 non-null    float64
#  7   DLY-SNWD-50PCTL          365 non-null    int64
#  8   DLY-SNOW-50PCTL          365 non-null    float64
#  9   DLY-PRCP-75PCTL          365 non-null    float64
#  10  DLY-SNWD-75PCTL          365 non-null    int64
#  11  DLY-SNOW-75PCTL          365 non-null    float64
#  12  MTD-PRCP-NORMAL          365 non-null    float64
#  13  MTD-SNOW-NORMAL          365 non-null    float64
# ...
